# %% [markdown]
# # COVID en Costa Rica al 30 de mayo de 2022

# %%
# Se acostumbra cargar pandas con el alias pd

import pandas as pd

# %%
# Carga de módulos de matplotlib
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# Datos generales COVID

# %%
# Carga de datos generales
covid_general = pd.read_csv("05_30_22_CSV_GENERAL.csv", sep=";")

# %%
covid_general
# Out:
#           FECHA  SE  positivos  nue_posi  conf_lab  conf_nexo  muj_posi  \
# 0    06/03/2020  10          2         2       NaN        NaN       NaN
# 1    07/03/2020  10          7         5       NaN        NaN       NaN
# 2    08/03/2020  11         10         3       NaN        NaN       NaN
# 3    09/03/2020  11         12         2       NaN        NaN       NaN
# 4    10/03/2020  11         13         1       NaN        NaN       7.0
# ..          ...  ..        ...       ...       ...        ...       ...
# 811  26/05/2022  21     896712      3499    3272.0      227.0  460886.0
# 812  27/05/2022  21     899404      2692    2491.0      201.0  462372.0
# 813  28/05/2022  21     901542      2138    1907.0      231.0  463595.0
# 814  29/05/2022  22     903213      1671    1603.0       68.0  464547.0
# 815  30/05/2022  22     904934      1721    1648.0       73.0  465503.0
#
#      hom_posi  extranj_posi  costar_posi  ...  CEACOINS_UCI  CEACOINS_SALON  \
# ...

# %%
covid_positivos = pd.read_csv("05_30_22_CSV_POSITIVOS.csv",
                              sep=";",
                              encoding="iso-8859-1")

covid_positivos
# Out:
#     cod_provin provincia  cod_canton        canton  15/03/2020  16/03/2020  \
# 0          1.0  San José       112.0        Acosta         0.0         0.0
# 1          1.0  San José       110.0    Alajuelita         0.0         0.0
# 2          1.0  San José       106.0        Aserrí         0.0         0.0
# 3          1.0  San José       118.0    Curridabat         0.0         0.0
# 4          1.0  San José       103.0  Desamparados         4.0         4.0
# ..         ...       ...         ...           ...         ...         ...
# 79         7.0     Limón       702.0        Pococí         0.0         0.0
# 80         7.0     Limón       703.0     Siquirres         0.0         0.0
# 81         7.0     Limón       704.0     Talamanca         0.0         0.0
# 82         9.0     Otros       999.0         Otros         0.0         0.0
# 83         NaN       NaN         NaN           NaN         NaN         NaN
#
# ...
